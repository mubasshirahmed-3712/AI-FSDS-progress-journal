# %% [markdown]
# <h1 style="text-align:center;">🌸 Iris Dataset – Matplotlib & Seaborn Mastery</h1>
#
# ### 🎯 Objective:
# To explore the Iris dataset through 30+ professional data visualizations using **Matplotlib** and **Seaborn**.
#
# ---
#
# ### 📊 Tools Used:
# - `pandas` for data handling
# - `matplotlib.pyplot` for plotting
# - `seaborn` for statistical visualizations
#
# ---
#
# ### 🧑‍💻 Prepared by: Mubasshir Ahmed
# ### 🕘 FSDS @10AM

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# Load the dataset
df = pd.read_csv(r'C:\Users\MUBASSHIR\OneDrive\Desktop\FSDS_TASKS\Projects\IrisViz-Matplotlib-Seaborn-Mastery\dataset\Iris.csv')

# Display first five rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 1 – Bar Plot: Count of Each Iris Species</h2>
#
# This **bar plot** shows the total number of samples for each species in the Iris dataset.
# It helps us check for **balanced class distribution** before modeling.

# %%
# Set Seaborn style for clean visuals
sns.set(style='whitegrid')

# ✅ Plot: Bar plot of species count
sns.countplot(x='Species', data=df, palette='Set2')

# ➤ Customize labels and title
plt.title('Count of Iris Species', fontsize=13)
plt.xlabel('Species')
plt.ylabel('Sample Count')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 2 – Jointplot: Sepal Length vs Sepal Width</h2>
#
# This **jointplot** combines a **scatter plot** with **histograms** to show the relationship between
# **Sepal Length** and **Sepal Width** across species.
# It helps visualize **distribution + correlation** between two key features.

# %%
# ✅ Jointplot: Sepal Length vs Sepal Width by species
sns.jointplot(data=df, x='SepalLengthCm', y='SepalWidthCm', hue='Species',
              kind='scatter', palette='Set1', height=6)

# ➤ Jointplot auto-displays; no need for plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 3 – Jointplot: Petal Length vs Petal Width</h2>
#
# This **jointplot** shows how **Petal Length** correlates with **Petal Width** across different species.
# Highly useful for identifying **cluster separation** between species.

# %%
# ✅ Jointplot: Petal Length vs Petal Width by species
sns.jointplot(data=df, x='PetalLengthCm', y='PetalWidthCm', hue='Species',
              kind='scatter', palette='Set2', height=6)

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 4 – Distribution of Sepal Length (Distplot)</h2>
#
# This **distribution plot** shows the spread of **Sepal Length** across species.
# It helps visualize **central tendency**, **spread**, and **overlapping patterns**.

# %%
# ✅ Distribution Plot (Histogram + KDE) for Sepal Length
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='SepalLengthCm', hue='Species', kde=True, palette='Set3', bins=15)

# ➤ Labels and title
plt.title('Distribution of Sepal Length by Species', fontsize=13)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 5 – Boxplot of Sepal Length by Species</h2>
#
# This **boxplot** shows the **median**, **quartiles**, and **outliers** of **Sepal Length** grouped by species.
# It’s a powerful tool to compare **distribution and variability** across species.

# %%
# ✅ Boxplot: Sepal Length grouped by Species
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Species', y='SepalLengthCm', palette='Set2')

# ➤ Labels and title
plt.title('Boxplot of Sepal Length by Species', fontsize=13)
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 6 – Heatmap: Correlation Matrix of Numerical Features</h2>
#
# This **heatmap** displays the **correlation coefficients** between numerical features.
# It helps identify which features are **positively or negatively related** — valuable for **feature selection**.

# %%
# ✅ Correlation Matrix
corr_matrix = df.drop('Id', axis=1).corr(numeric_only=True)

# ✅ Heatmap of correlations
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# ➤ Title
plt.title('Feature Correlation Heatmap', fontsize=13)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 7 – KDE Plot: Sepal Width Density by Species</h2>
#
# KDE plot (Kernel Density Estimate) shows **smooth distribution curves** for Sepal Width,
# helpful for comparing **data spread and peak values** across species.

# %%
plt.figure(figsize=(8, 5))
sns.kdeplot(data=df, x='SepalWidthCm', hue='Species', fill=True, palette='pastel')
plt.title('KDE Plot: Sepal Width by Species', fontsize=13)
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 8 – Pairplot of All Numerical Features</h2>
#
# **Pairplot** displays **scatter plots + KDE plots** for all feature pairs,
# highlighting **relationships and separability** of species clusters.

# %%
sns.pairplot(df.drop('Id', axis=1), hue='Species', palette='Set1', diag_kind='kde')
plt.suptitle('Pairplot of Features by Species', fontsize=14, y=1.02)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 9 – Violin Plot: Petal Width by Species</h2>
#
# **Violin plots** combine boxplots and KDE,
# helping visualize **distribution + density + outliers**.

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Species', y='PetalWidthCm', palette='Set2')
plt.title('Violin Plot of Petal Width by Species', fontsize=13)
plt.xlabel('Species')
plt.ylabel('Petal Width (cm)')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 10 – Strip Plot: Sepal Width by Species</h2>
#
# Strip plots help visualize **individual data points** with **jitter** for clarity.
# Useful for small datasets and detecting overlaps.

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(data=df, x='Species', y='SepalWidthCm', palette='Set1', jitter=True)
plt.title('Strip Plot of Sepal Width by Species', fontsize=13)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 11 – Swarm Plot: Petal Length by Species</h2>
#
# Swarm plots show **non-overlapping data points** grouped by category.
# They preserve **data density and distribution** visually.

# %%
plt.figure(figsize=(8, 5))
sns.swarmplot(data=df, x='Species', y='PetalLengthCm', palette='Set3')
plt.title('Swarm Plot of Petal Length by Species', fontsize=13)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 12 – Histogram: Petal Length Distribution</h2>
#
# Histograms reveal the **frequency distribution** of numerical data,
# highlighting **skewness, peaks, and spread**.

# %%
plt.hist(df['PetalLengthCm'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Petal Length')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 13 – FacetGrid KDE: Sepal Length by Species</h2>
#
# FacetGrid allows **multiple KDE plots** per species,
# enabling **side-by-side density comparison**.

# %%
g = sns.FacetGrid(df, hue='Species', height=5)
g.map(sns.kdeplot, 'SepalLengthCm', fill=True)
g.add_legend()
plt.title('FacetGrid KDE of Sepal Length')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 14 – Violin Plot: Sepal Width by Species</h2>
#
# Violin plots show **data distribution and density** across categories,
# combining box plot and KDE in one view.

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Species', y='SepalWidthCm', palette='Set2')
plt.title('Violin Plot of Sepal Width by Species', fontsize=13)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 15 – Pair Plot: All Numerical Columns</h2>
#
# Pair plots display **pairwise scatter plots** for all numerical features,
# helpful in exploring **relationships** and **species separation**.

# %%
sns.pairplot(df, hue='Species', palette='husl')
plt.suptitle('Pair Plot of Iris Features by Species', y=1.02)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 16 – Joint Plot: Sepal Length vs Sepal Width</h2>
#
# Joint plots combine a **scatter plot** with **marginal histograms**
# to analyze **bivariate relationships** and distributions.

# %%
sns.jointplot(data=df, x='SepalLengthCm', y='SepalWidthCm', kind='scatter', hue='Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 17 – Heatmap: Correlation Matrix</h2>
#
# Heatmaps visualize **correlation coefficients** among features,
# revealing **strong or weak linear relationships**.

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap', fontsize=13)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 18 – Boxen Plot: Petal Length by Species</h2>
#
# Boxen plots show **data distribution** with emphasis on the **tails**,
# useful for **large datasets** with many outliers.

# %%
sns.boxenplot(data=df, x='Species', y='PetalLengthCm', palette='pastel')
plt.title('Boxen Plot of Petal Length by Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 19 – KDE Plot: Petal Width by Species</h2>
#
# KDE (Kernel Density Estimate) plots show **smooth distribution curves**
# for comparing **feature densities** across species.

# %%
sns.kdeplot(data=df, x='PetalWidthCm', hue='Species', fill=True)
plt.title('KDE Plot of Petal Width by Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 20 – Count Plot: Species Distribution</h2>
#
# Count plots show the **frequency** of each category.
# Used here to visualize the **number of samples per species**.

# %%
sns.countplot(data=df, x='Species', palette='Set3')
plt.title('Count Plot of Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 21 – Histogram with KDE: Sepal Length</h2>
#
# Combined **histogram + KDE** shows distribution of Sepal Length
# and its **smoothed density curve**.

# %%
sns.histplot(data=df, x='SepalLengthCm', kde=True, color='skyblue')
plt.title('Histogram + KDE of Sepal Length')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 22 – Multiple KDE Curves: Sepal Width by Species</h2>
#
# Overlay KDE plots compare **sepal width density** among species.

# %%
for species in df['Species'].unique():
    sns.kdeplot(df[df['Species'] == species]['SepalWidthCm'], label=species)
plt.title('Sepal Width Distribution by Species')
plt.legend()
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 23 – Rug Plot: Petal Length</h2>
#
# Rug plots show **distribution marks** on axis,
# helpful to see **individual data points**.

# %%
sns.rugplot(data=df, x='PetalLengthCm')
plt.title('Rug Plot of Petal Length')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 24 – Line Plot: Sepal Length vs Index</h2>
#
# Line plot shows **trend of Sepal Length** across dataset index.

# %%
plt.plot(df.index, df['SepalLengthCm'], color='purple')
plt.title('Line Plot of Sepal Length Over Index')
plt.xlabel('Index')
plt.ylabel('Sepal Length (cm)')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 25 – Area Plot: All Features (Cumulative)</h2>
#
# Stacked area plots visualize **accumulated values**
# for all numerical features across rows.

# %%
df_num = df.drop('Species', axis=1)
df_num.plot(kind='area', figsize=(10, 5), alpha=0.4)
plt.title('Area Plot of All Features')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 26 – Hexbin Plot: Petal Length vs Width</h2>
#
# Hexbin plots group data into **hexagonal bins**,
# ideal for **dense scatter data**.

# %%
df.plot.hexbin(x='PetalLengthCm', y='PetalWidthCm', gridsize=25, cmap='Blues', figsize=(7, 5))
plt.title('Hexbin Plot of Petal Length vs Width')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 27 – Strip Plot: Petal Width by Species</h2>
#
# Strip plots show **all data points** with jitter,
# useful for small datasets like Iris.

# %%
sns.stripplot(data=df, x='Species', y='PetalWidthCm', jitter=True, palette='Set1')
plt.title('Strip Plot of Petal Width by Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 28 – Swarm Plot: Sepal Width by Species</h2>
#
# Swarm plots avoid **overlapping data points**,
# great for visualizing all values by category.

# %%
sns.swarmplot(data=df, x='Species', y='SepalWidthCm', palette='Set2')
plt.title('Swarm Plot of Sepal Width by Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 29 – Violin Plot: Petal Width by Species</h2>
#
# Violin plots combine **boxplot + KDE**,
# great for showing **distribution + spread**.

# %%
sns.violinplot(data=df, x='Species', y='PetalWidthCm', palette='Pastel1')
plt.title('Violin Plot of Petal Width by Species')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 30 – Heatmap of Correlation Matrix</h2>
#
# Correlation matrix helps identify **relationships between features**.
# Heatmap makes it visually intuitive.

# %%
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Heatmap of Feature Correlations')
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 31 – Pair Plot: All Features Colored by Species</h2>
#
# Pair plots create **all possible scatter plots** between features.
# It reveals **class separation** and feature patterns.

# %%
sns.pairplot(df, hue='Species', palette='Set1')
plt.suptitle('Pair Plot of All Features by Species', y=1.02)
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 32 – 3D Scatter Plot: Sepal & Petal Dimensions</h2>
#
# Visualize **three dimensions** of Iris dataset using 3D scatter.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

for species in df['Species'].unique():
    subset = df[df['Species'] == species]
    ax.scatter(subset['SepalLengthCm'], subset['PetalLengthCm'], subset['PetalWidthCm'], label=species)

ax.set_xlabel('Sepal Length')
ax.set_ylabel('Petal Length')
ax.set_zlabel('Petal Width')
plt.title('3D Scatter Plot of Iris Dimensions')
plt.legend()
plt.show()

# %% [markdown]
# <h2 style="text-align:center;">📊 Plot 33 – Radar Chart (Spider Plot) of Mean Feature per Species</h2>
#
# Radar charts help compare **multidimensional mean values**
# for each species in a circular layout.

# %%
# Calculate means
df_mean = df.groupby('Species').mean(numeric_only=True)

# Features to plot
labels = df_mean.columns.tolist()
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]  # Complete the circle

# Create Radar Chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))

for index, row in df_mean.iterrows():
    values = row.tolist()
    values += values[:1]
    ax.plot(angles, values, label=index)
    ax.fill(angles, values, alpha=0.1)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title('Radar Chart of Mean Feature per Species')
plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))
plt.show()

# %% [markdown]
# <h2 style="text-align: center;">📝 Summary – IrisViz: 33 Visualizations Mastered</h2>
#
# Over the course of this project, we explored the **Iris dataset** using a wide range of **33 professional visualizations**.
# Each plot was crafted to analyze **feature distributions, inter-variable relationships, and species-specific patterns**.
#
# ---
#
# ### 📊 Visualization Techniques Covered:
#
# | Category                   | Visualization Type                                 |
# |---------------------------|----------------------------------------------------|
# | **Basic Plots**           | Line, Bar, Horizontal Bar, Pie, Area               |
# | **Distribution Plots**    | Histogram, KDE Plot, Box Plot, Violin Plot         |
# | **Comparison Plots**      | Scatter, Stacked Bar, Error Bar, Joint Plot        |
# | **Multi-variate Plots**   | Pair Plot, Heatmap, 3D Scatter, Radar Chart        |
# | **Advanced Seaborn**      | Strip Plot, Swarm Plot, FacetGrid, CatPlot         |
# | **Specialty Plots**       | Contour Plot, Count Plot, LM Plot                  |
#
# ---
#
# ### 🎯 Key Takeaways:
#
# - ✅ Applied **Matplotlib & Seaborn** with professional formatting and color palettes
# - ✅ Visualized **data distributions, trends, and interdependencies**
# - ✅ Practiced **effective chart selection** for different data patterns
# - ✅ Improved **data storytelling** and visual communication skills
#
# ---
#
# <h3 style="text-align:center;">✨ This notebook is a complete visual handbook for Iris dataset analysis.
# Ideal for Data Science, Analytics, and ML visualization projects.</h3>
